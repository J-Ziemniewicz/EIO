# %% [markdown]
# Given is a set of 19 stores from pharmacy-consmetics-hygiene sector in Portugal. They are evaluated using 5 inputs and 2 outputs descibled below. We need to analyse their efficiency.
#
# Inputs
# - i1: Average stock - Average value of inventory (in euros);
# - i2: Number of employees - Number of full-time equivalent employees;
# - i3: Salary costs - Total cost with salaries (in euros);
# - i4: Rent - Cost of space (in euros);
# - i5: Area - Total area of the store (m^2)
#
# Outputs:
# - o1: Global sales - Global value of sales (in euros);
# - o2: Family 4 sales/Global sales - Proportion of Family 4 products in global sales

# %% [markdown]
# Load necessry package

# %%
library(lpSolveAPI)

# %% [markdown]
# ### Inputs

# %%
inputs <- read.csv("inputs.csv", sep=";")
# inputs = inputs[1:7, ]
inputs
# Out:
#    X   i1     i2   i3     i4     i5
# 1  s1  360614 13.2 153071 275240 213
# 2  s2  263736  9.5 111409 117916 213
# 3  s3  628938 17.8 218122 492305 436
# 4  s4  479582 16.5 189495 134824 262
# 5  s5  600449 15.9 222567 411982 331
# 6  s6  299876 12.3 159338 185368 208
# 7  s7  171010  9.2  92436 124355 231
# 8  s8  354506 13.9 153228 231525 400
# 9  s9  521819 13.1 155918 145527 222
# 10 s10 357204  7.3  96041 179931 200
# 11 s11 307347 11.3 135895 171760 313
# 12 s12 701109 15.8 214814 300106 290
# 13 s13 392894 15.2 170675 250726 216
# 14 s14 604291 20.0 222424 387543 443
# 15 s15 272851 12.0 148268 159532 197
# 16 s16 327304 11.9 181352 168006 207
# 17 s17 356157 11.5 130337 181693 286
# 18 s18 152850 11.4  87223 147252 301
# 19 s19 295598 13.3 193606 160607 199

# %% [markdown]
# ### Outputs

# %%
outputs <- read.csv("outputs.csv", sep=";")
# outputs = outputs[1:7, ]
outputs
# Out:
#    X   o1      o2
# 1  s1  1994652 36.4
# 2  s2  1194289 44.6
# 3  s3  3841226 32.2
# 4  s4  2299879 23.8
# 5  s5  3905880 39.7
# 6  s6  1554821 37.2
# 7  s7   625315 22.0
# 8  s8  1570432 24.4
# 9  s9  2249522 28.0
# 10 s10 1505312 45.4
# 11 s11 1387585 28.1
# 12 s12 5425809 32.4
# 13 s13 2269410 40.5
# 14 s14 3410820 27.8
# 15 s15 1410839 33.9
# 16 s16 1263137 29.1
# 17 s17 1371183 26.5
# 18 s18  877671 32.6
# 19 s19 1634121 26.0

# %% [markdown]
# # BCC
# ## Input-oriented DUAL model

# %%
createModel = function()
{
    return(make.lp(ncol = 1 + nrow(inputs))) #variables 1 for theta, 2:20 - lambdas
}
model <- createModel()

# %% [markdown]
# Set model's optimization direction.

# %%
setDirection = function(model) 
{
    lp.control(model, sense="min")
}

# %% [markdown]
# Model objective function.

# %%
setObjective = function(model, inputs, outputs)
{
    set.objfn(model, c(1), indices = c(1)) 
}

# %% [markdown]
# Combination of inputs not greater than analyzed DMU multiplied by $\theta$

# %%
addConstraintsWithTheta = function(model, inputs, outputs, storeID)
{
    for(i in 2:ncol(inputs))
    {
        constraint_coeffs = array(0, dim=(1+nrow(inputs)))
        constraint_coeffs[1] = -1*inputs[storeID, i]
        constraint_coeffs[2:(1+nrow(inputs))] = unlist(c(inputs[, i]))
        add.constraint(model, constraint_coeffs, "<=", 0) 
    }
}

# %% [markdown]
# Combination of outputs not less than analyzed DMU

# %%
addOutputNotLessConstraints = function(model, inputs, outputs, storeID)
{
    for(i in 2:ncol(outputs)) # one constraint for each DMU
    {
        constraint_coeffs = array(0, dim=(1+nrow(inputs)))
        constraint_coeffs[2:(1+nrow(inputs))] = unlist(c(outputs[, i]))
        add.constraint(model, constraint_coeffs, ">=", outputs[storeID, i])
    }
}

# %% [markdown]
# Combination should be convex -- lambdas must sum to 1

# %%
addLambdasMustSumToOneConstraint = function(model, inputs, outputs)
{
    constraint_coeffs = array(1, dim=(1+nrow(inputs)))
    constraint_coeffs[1] = 0
    add.constraint(model, constraint_coeffs, "=", 1)
}

# %% [markdown]
# Function prepareModel creates model and adds all constraints

# %%
prepareModel = function(inputs, outputs, storeId)
{
    model = createModel()
    setDirection(model)
    setObjective(model, inputs, outputs)
    addConstraintsWithTheta(model, inputs, outputs, storeId)
    addOutputNotLessConstraints(model, inputs, outputs, storeId)
    addLambdasMustSumToOneConstraint(model, inputs, outputs)
    
    return(model)
}

# %% [markdown]
# Save model to file (large model is not printed)

# %%
model = prepareModel(inputs, outputs, 1)
print(model)
write.lp(model, filename="model.lp")
# Out:
# Model name:
#   a linear program with 20 decision variables and 8 constraints

# %%
inputs <- read.csv("inputs.csv", sep=";")
outputs <- read.csv("outputs.csv", sep=";")

for(storeId in 1:nrow(inputs))
{
    model = prepareModel(inputs, outputs, storeId)
    solve(model)
    
    efficiency = get.objective(model)
    cat("Store", storeId)
    cat("\tInputs:  ")
    for (i in inputs[storeId, 2:ncol(inputs)]){
        cat(i, "\t")
    }
    cat("\n\tOutputs: ")
    for (i in outputs[storeId, 2:ncol(outputs)]){
        cat(i, "\t")
    }
    
    
    cat("\n\n>>>Efficiency:", efficiency, "\n\n", sep="")
    vars = get.variables(model) #first - theta, rest - lambdas 
    for (i in 2:length(vars)) {
        if(vars[i] > 0){
            cat("lambda_", i-1, ": ",vars[i], "\n", sep="")
        }
    }
    
    
    if(efficiency < 0.9999999) #not 1, because of numerical precision error 
    {
        cat("\nStore is not efficient, making efficient convex combination\n\n")
        
        effective_inputs = array(0, length(inputs)-1)
        effective_outputs = array(0, length(outputs)-1) 
        
        for(inputIdx in 1:(length(inputs)-1)) {
            for(i in 2:length(vars)) {
                effective_inputs[inputIdx] = effective_inputs[inputIdx] + vars[i] * inputs[i-1, inputIdx+1]
            }
                
        }
            
        for(outputIdx in 1:(length(outputs)-1)) {
            for(i in 2:length(vars)) {
                effective_outputs[outputIdx] = effective_outputs[outputIdx] + vars[i] * outputs[i-1, outputIdx+1]
            }
        }
        cat("Effective inputs:", effective_inputs, "\t(should be better than original)\n")
        cat("Effective outputs:", effective_outputs, "\t\t\t\t(should not be worse than original)\n")
        
        reduce_inputs_by = inputs[storeId, 2:length(inputs)] - effective_inputs
        cat("\nIt should reduce inputs by:", paste(round(reduce_inputs_by, 2)), "\n")
    }
#     else {
#         cat("Store is efficient\n")
#     }
    
    cat("\n--------------------------------------------------------\n")
}
# Out:
# Store 1	Inputs:  360614 	13.2 	153071 	275240 	213
# 	Outputs: 1994652 	36.4
#
# >>>Efficiency:0.9870769
#
# lambda_10: 0.2322581
# lambda_12: 0.1060539
# lambda_13: 0.1298732
# lambda_15: 0.4218086
# lambda_19: 0.1100063
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 355953.8 11.86999 151092.9 191140.2 210.2474 	(should be better than original)
# Effective outputs: 1994652 36.4 				(should not be worse than original)
#
# It should reduce inputs by: 4660.24 1.33 1978.15 84099.84 2.75
#
# --------------------------------------------------------
# Store 2	Inputs:  263736 	9.5 	111409 	117916 	213
# 	Outputs: 1194289 	44.6
#
# >>>Efficiency:1
#
# lambda_2: 1
#
# --------------------------------------------------------
# Store 3	Inputs:  628938 	17.8 	218122 	492305 	436
# 	Outputs: 3841226 	32.2
#
# >>>Efficiency:0.8110404
#
# lambda_12: 0.6515974
# lambda_18: 0.3484026
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 510094.2 14.26703 170361 246851.3 293.8324 	(should be better than original)
# Effective outputs: 3841226 32.46968 				(should not be worse than original)
#
# It should reduce inputs by: 118843.85 3.53 47761.03 245453.73 142.17
#
# --------------------------------------------------------
# Store 4	Inputs:  479582 	16.5 	189495 	134824 	262
# 	Outputs: 2299879 	23.8
#
# >>>Efficiency:1
#
# lambda_4: 1
#
# --------------------------------------------------------
# Store 5	Inputs:  600449 	15.9 	222567 	411982 	331
# 	Outputs: 3905880 	39.7
#
# >>>Efficiency:1
#
# lambda_5: 1
#
# --------------------------------------------------------
# Store 6	Inputs:  299876 	12.3 	159338 	185368 	208
# 	Outputs: 1554821 	37.2
#
# >>>Efficiency:0.9850411
#
# lambda_2: 0.2226988
# lambda_12: 0.017316
# lambda_13: 0.1428935
# lambda_15: 0.6170917
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 295390.2 11.96631 144413.7 165729.4 204.8885 	(should be better than original)
# Effective outputs: 1554821 37.2 				(should not be worse than original)
#
# It should reduce inputs by: 4485.82 0.33 14924.33 19638.62 3.11
#
# --------------------------------------------------------
# Store 7	Inputs:  171010 	9.2 	92436 	124355 	231
# 	Outputs: 625315 	22
#
# >>>Efficiency:1
#
# lambda_7: 1
#
# --------------------------------------------------------
# Store 8	Inputs:  354506 	13.9 	153228 	231525 	400
# 	Outputs: 1570432 	24.4
#
# >>>Efficiency:0.7662112
#
# lambda_7: 0.725951
# lambda_12: 0.1925973
# lambda_18: 0.08145169
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 271626.5 10.65034 115581.1 160069.2 248.0649 	(should be better than original)
# Effective outputs: 1570432 24.8664 				(should not be worse than original)
#
# It should reduce inputs by: 82879.53 3.25 37646.94 71455.83 151.94
#
# --------------------------------------------------------
# Store 9	Inputs:  521819 	13.1 	155918 	145527 	222
# 	Outputs: 2249522 	28
#
# >>>Efficiency:1
#
# lambda_9: 1
#
# --------------------------------------------------------
# Store 10	Inputs:  357204 	7.3 	96041 	179931 	200
# 	Outputs: 1505312 	45.4
#
# >>>Efficiency:1
#
# lambda_10: 1
#
# --------------------------------------------------------
# Store 11	Inputs:  307347 	11.3 	135895 	171760 	313
# 	Outputs: 1387585 	28.1
#
# >>>Efficiency:0.8737095
#
# lambda_2: 0.162227
# lambda_7: 0.620252
# lambda_10: 0.09545763
# lambda_12: 0.1220634
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 268532 9.872917 110795.9 150068.3 232.3225 	(should be better than original)
# Effective outputs: 1387585 29.1695 				(should not be worse than original)
#
# It should reduce inputs by: 38815.01 1.43 25099.07 21691.66 80.68
#
# --------------------------------------------------------
# Store 12	Inputs:  701109 	15.8 	214814 	300106 	290
# 	Outputs: 5425809 	32.4
#
# >>>Efficiency:1
#
# lambda_12: 1
#
# --------------------------------------------------------
# Store 13	Inputs:  392894 	15.2 	170675 	250726 	216
# 	Outputs: 2269410 	40.5
#
# >>>Efficiency:1
#
# lambda_13: 1
#
# --------------------------------------------------------
# Store 14	Inputs:  604291 	20 	222424 	387543 	443
# 	Outputs: 3410820 	27.8
#
# >>>Efficiency:0.7582614
#
# lambda_12: 0.556964
# lambda_18: 0.443036
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 458210.5 13.85064 158286.6 232386.2 294.8734 	(should be better than original)
# Effective outputs: 3410820 32.48861 				(should not be worse than original)
#
# It should reduce inputs by: 146080.49 6.15 64137.41 155156.83 148.13
#
# --------------------------------------------------------
# Store 15	Inputs:  272851 	12 	148268 	159532 	197
# 	Outputs: 1410839 	33.9
#
# >>>Efficiency:1
#
# lambda_15: 1
#
# --------------------------------------------------------
# Store 16	Inputs:  327304 	11.9 	181352 	168006 	207
# 	Outputs: 1263137 	29.1
#
# >>>Efficiency:0.9558258
#
# lambda_2: 0.03169783
# lambda_10: 0.1162613
# lambda_15: 0.8520409
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 282369.1 11.37433 141027.7 160584.5 197.8559 	(should be better than original)
# Effective outputs: 1414958 35.57617 				(should not be worse than original)
#
# It should reduce inputs by: 44934.94 0.53 40324.33 7421.52 9.14
#
# --------------------------------------------------------
# Store 17	Inputs:  356157 	11.5 	130337 	181693 	286
# 	Outputs: 1371183 	26.5
#
# >>>Efficiency:0.8124676
#
# lambda_2: 0.4976488
# lambda_10: 0.3173147
# lambda_12: 0.03007553
# lambda_18: 0.1549609
#
# Store is not efficient, making efficient convex combination
#
# Effective inputs: 289366 9.285809 105894.6 147619.7 224.8273 	(should be better than original)
# Effective outputs: 1371183 42.6274 				(should not be worse than original)
#
# It should reduce inputs by: 66790.99 2.21 24442.42 34073.33 61.17
#
# --------------------------------------------------------
# Store 18	Inputs:  152850 	11.4 	87223 	147252 	301
# 	Outputs: 877671 	32.6
#
# >>>Efficiency:1
#
# lambda_18: 1
#
# --------------------------------------------------------
# Store 19	Inputs:  295598 	13.3 	193606 	160607 	199
# 	Outputs: 1634121 	26
#
# >>>Efficiency:1
#
# lambda_19: 1
#
# --------------------------------------------------------
